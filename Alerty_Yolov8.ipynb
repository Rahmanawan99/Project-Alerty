# %%
! pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 585.5/585.5 kB 21.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 205.1/205.1 kB 25.6 MB/s eta 0:00:00
# ...

# %%
#checking the verison of Pytorch
import torch
print(torch.__version__)
# Out:
# 2.0.0+cu118

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Chaning to the directory containing the data
# %cd /content/drive/MyDrive/Yolo8_v4
# Out:
# /content/drive/.shortcut-targets-by-id/11qmoMxN0yjSVNKCMPjFpv-zNRhJRCRce/Yolo8_v4

# %%
#Importing Yolo
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.104 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.4/78.2 GB disk)

# %%
#Training Yolov8 on Dataset
# !yolo task=detect mode=train epochs=70 data=/content/drive/MyDrive/Yolo8_v4/data.yaml model=yolov8m.pt imgsz=640 batch=8
# Out:
# Ultralytics YOLOv8.0.104 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
#Prediction on video
# !yolo task=detect mode=predict model=runs/detect/train7/weights/best.pt conf=0.55 source=a.mp4 save=True
# Out:
# Ultralytics YOLOv8.0.104 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients
#
# video 1/1 (1/409) /content/drive/.shortcut-targets-by-id/11qmoMxN0yjSVNKCMPjFpv-zNRhJRCRce/Yolo8_v4/a.mp4: 384x640 3 With Helmets, 65.1ms
# video 1/1 (2/409) /content/drive/.shortcut-targets-by-id/11qmoMxN0yjSVNKCMPjFpv-zNRhJRCRce/Yolo8_v4/a.mp4: 384x640 3 With Helmets, 25.2ms
# video 1/1 (3/409) /content/drive/.shortcut-targets-by-id/11qmoMxN0yjSVNKCMPjFpv-zNRhJRCRce/Yolo8_v4/a.mp4: 384x640 3 With Helmets, 25.2ms
# video 1/1 (4/409) /content/drive/.shortcut-targets-by-id/11qmoMxN0yjSVNKCMPjFpv-zNRhJRCRce/Yolo8_v4/a.mp4: 384x640 3 With Helmets, 25.1ms
# video 1/1 (5/409) /content/drive/.shortcut-targets-by-id/11qmoMxN0yjSVNKCMPjFpv-zNRhJRCRce/Yolo8_v4/a.mp4: 384x640 3 With Helmets, 25.2ms
# ...

# %%
#Prediction on video
# !yolo task=detect mode=predict model=runs/detect/train7/weights/best.pt conf=0.55 source=b.mp4 save=True
# Out:
# Ultralytics YOLOv8.0.104 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients
#
# video 1/1 (1/395) /content/drive/.shortcut-targets-by-id/11qmoMxN0yjSVNKCMPjFpv-zNRhJRCRce/Yolo8_v4/b.mp4: 384x640 1 No Helmet, 92.4ms
# video 1/1 (2/395) /content/drive/.shortcut-targets-by-id/11qmoMxN0yjSVNKCMPjFpv-zNRhJRCRce/Yolo8_v4/b.mp4: 384x640 1 No Helmet, 25.3ms
# video 1/1 (3/395) /content/drive/.shortcut-targets-by-id/11qmoMxN0yjSVNKCMPjFpv-zNRhJRCRce/Yolo8_v4/b.mp4: 384x640 1 No Helmet, 25.2ms
# video 1/1 (4/395) /content/drive/.shortcut-targets-by-id/11qmoMxN0yjSVNKCMPjFpv-zNRhJRCRce/Yolo8_v4/b.mp4: 384x640 1 No Helmet, 25.2ms
# video 1/1 (5/395) /content/drive/.shortcut-targets-by-id/11qmoMxN0yjSVNKCMPjFpv-zNRhJRCRce/Yolo8_v4/b.mp4: 384x640 1 No Helmet, 25.2ms
# video 1/1 (6/395) /content/drive/.shortcut-targets-by-id/11qmoMxN0yjSVNKCMPjFpv-zNRhJRCRce/Yolo8_v4/b.mp4: 384x640 1 No Helmet, 25.2ms
# ...

# %%
#Prediction on video
# !yolo task=detect mode=predict model=runs/detect/train7/weights/best.pt conf=0.30 source=c.mp4 save=True
# Out:
# Streaming output truncated to the last 5000 lines.
# video 1/1 (2953/7950) /content/drive/.shortcut-targets-by-id/11qmoMxN0yjSVNKCMPjFpv-zNRhJRCRce/Yolo8_v4/c.mp4: 384x640 1 No Helmet, 1 With Helmet, 12.0ms
# video 1/1 (2954/7950) /content/drive/.shortcut-targets-by-id/11qmoMxN0yjSVNKCMPjFpv-zNRhJRCRce/Yolo8_v4/c.mp4: 384x640 1 With Helmet, 12.8ms
# video 1/1 (2955/7950) /content/drive/.shortcut-targets-by-id/11qmoMxN0yjSVNKCMPjFpv-zNRhJRCRce/Yolo8_v4/c.mp4: 384x640 1 With Helmet, 11.8ms
# video 1/1 (2956/7950) /content/drive/.shortcut-targets-by-id/11qmoMxN0yjSVNKCMPjFpv-zNRhJRCRce/Yolo8_v4/c.mp4: 384x640 1 No Helmet, 12.0ms
# video 1/1 (2957/7950) /content/drive/.shortcut-targets-by-id/11qmoMxN0yjSVNKCMPjFpv-zNRhJRCRce/Yolo8_v4/c.mp4: 384x640 (no detections), 12.7ms
# video 1/1 (2958/7950) /content/drive/.shortcut-targets-by-id/11qmoMxN0yjSVNKCMPjFpv-zNRhJRCRce/Yolo8_v4/c.mp4: 384x640 (no detections), 12.0ms
# ...

# %%
#Prediction on video
# !yolo task=detect mode=predict model=runs/detect/train7/weights/best.pt conf=0.55 source=d.mp4 save=True
# Out:
# Ultralytics YOLOv8.0.104 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients
#
# video 1/1 (1/2283) /content/drive/.shortcut-targets-by-id/11qmoMxN0yjSVNKCMPjFpv-zNRhJRCRce/Yolo8_v4/d.mp4: 384x640 (no detections), 122.6ms
# video 1/1 (2/2283) /content/drive/.shortcut-targets-by-id/11qmoMxN0yjSVNKCMPjFpv-zNRhJRCRce/Yolo8_v4/d.mp4: 384x640 (no detections), 25.8ms
# video 1/1 (3/2283) /content/drive/.shortcut-targets-by-id/11qmoMxN0yjSVNKCMPjFpv-zNRhJRCRce/Yolo8_v4/d.mp4: 384x640 (no detections), 25.8ms
# video 1/1 (4/2283) /content/drive/.shortcut-targets-by-id/11qmoMxN0yjSVNKCMPjFpv-zNRhJRCRce/Yolo8_v4/d.mp4: 384x640 (no detections), 26.6ms
# video 1/1 (5/2283) /content/drive/.shortcut-targets-by-id/11qmoMxN0yjSVNKCMPjFpv-zNRhJRCRce/Yolo8_v4/d.mp4: 384x640 (no detections), 25.8ms
# ...

# %%
#Prediction on video
# !yolo task=detect mode=predict model=runs/detect/train7/weights/best.pt conf=0.75 source=e.mp4 save=True
# Out:
# Streaming output truncated to the last 5000 lines.
# video 1/1 (8264/13261) /content/drive/.shortcut-targets-by-id/11qmoMxN0yjSVNKCMPjFpv-zNRhJRCRce/Yolo8_v4/e.mp4: 384x640 (no detections), 11.9ms
# video 1/1 (8265/13261) /content/drive/.shortcut-targets-by-id/11qmoMxN0yjSVNKCMPjFpv-zNRhJRCRce/Yolo8_v4/e.mp4: 384x640 (no detections), 11.8ms
# video 1/1 (8266/13261) /content/drive/.shortcut-targets-by-id/11qmoMxN0yjSVNKCMPjFpv-zNRhJRCRce/Yolo8_v4/e.mp4: 384x640 (no detections), 12.7ms
# video 1/1 (8267/13261) /content/drive/.shortcut-targets-by-id/11qmoMxN0yjSVNKCMPjFpv-zNRhJRCRce/Yolo8_v4/e.mp4: 384x640 (no detections), 13.3ms
# video 1/1 (8268/13261) /content/drive/.shortcut-targets-by-id/11qmoMxN0yjSVNKCMPjFpv-zNRhJRCRce/Yolo8_v4/e.mp4: 384x640 (no detections), 12.9ms
# video 1/1 (8269/13261) /content/drive/.shortcut-targets-by-id/11qmoMxN0yjSVNKCMPjFpv-zNRhJRCRce/Yolo8_v4/e.mp4: 384x640 (no detections), 12.1ms
# ...

# %%
#Prediction on an image
# !yolo task=detect mode=predict model=runs/detect/train7/weights/best.pt conf=0.35 source=test/images save=True
# Out:
# Ultralytics YOLOv8.0.104 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients
#
# image 1/571 /content/drive/.shortcut-targets-by-id/11qmoMxN0yjSVNKCMPjFpv-zNRhJRCRce/Yolo8_v4/test/images/000008_jpg.rf.9d8ee21da569ae852a3f2b3376f4aede.jpg: 640x640 2 No Helmets, 8 With Helmets, 36.2ms
# image 2/571 /content/drive/.shortcut-targets-by-id/11qmoMxN0yjSVNKCMPjFpv-zNRhJRCRce/Yolo8_v4/test/images/000010_jpg.rf.f64bb73fd6ff4634f9cdbe1b672c73c8.jpg: 640x640 5 With Helmets, 36.2ms
# image 3/571 /content/drive/.shortcut-targets-by-id/11qmoMxN0yjSVNKCMPjFpv-zNRhJRCRce/Yolo8_v4/test/images/000026_jpg.rf.31dd391779bf09a78f0897c45ac7c3bb.jpg: 640x640 2 With Helmets, 36.3ms
# image 4/571 /content/drive/.shortcut-targets-by-id/11qmoMxN0yjSVNKCMPjFpv-zNRhJRCRce/Yolo8_v4/test/images/000027_jpg.rf.4791fe1a72fe6ed889665cd373eaa72a.jpg: 640x640 4 With Helmets, 36.3ms
# ...

# %%
#Prediction on webcam
# !yolo task=detect mode=predict model=runs/detect/train6/weights/best.pt conf=0.35 source=0 show=True
